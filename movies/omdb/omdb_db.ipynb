# %% [markdown]
# ### Reading omdb

# %%
import os
import tempfile
import requests
import pandas as pd
import sqlite3
import shutil

df = pd.read_csv('omdb_movie_data.csv')
df
# Out:
# /home/wolf/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)
#                         Title  Year   Rated     Released  Runtime  \
# 0    The Silence of the Lambs  1991       R  14 Feb 1991  118 min
# 1               Trainspotting  1996       R  09 Aug 1996   93 min
# 2                 The General  1926  Passed  02 Jan 1927   78 min
# 3             The Dark Knight  2008   PG-13  18 Jul 2008  152 min
# 4                  Unforgiven  1992       R  07 Aug 1992  130 min
# ..                        ...   ...     ...          ...      ...
# 243    No Country for Old Men  2007       R  21 Nov 2007  122 min
# 244                      Coco  2017      PG  22 Nov 2017  105 min
# 245   Spider-Man: No Way Home  2021   PG-13  17 Dec 2021  148 min
# 246               Gran Torino  2008       R  09 Jan 2009  116 min
# ...
